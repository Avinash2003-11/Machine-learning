# %%
import pandas as pd
from datetime import datetime
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}


df = pd.DataFrame(data)


print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from datetime import datetime
#       3 data = {
#       4     'Name': ['Alice', 'Bob', 'Charlie'],
#       5     'Age': [25, 30, 35],
#       6     'City': ['New York', 'Los Angeles', 'Chicago']
#       7 }
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.6 MB 14.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 17.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.6 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 18.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/12.9 MB 18.5 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.9 MB 13.0 MB/s eta 0:00:01
#    ------------------ --------------------- 6.0/12.9 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.9 MB 8.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}


df = pd.DataFrame(data)
df
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["number"] = ["365", "456", "369"]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df["id"] = ["vc345", "vc963", "vc963"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["id"] = ["vc345", "vc963", "vc963"]
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}


df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df["number"] = ["12", "25", "65"]

# %%
df
# Out:
#       Name  Age         City number
# 0    Alice   25     New York     12
# 1      Bob   30  Los Angeles     25
# 2  Charlie   35      Chicago     65

# %%
df["name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\avinash\Downloads\my projects\machine learning projects\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["name"]
#
# ...

# %%
df[name]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[name]
#
# NameError: name 'name' is not defined

# %%
df
# Out:
#       Name  Age         City number
# 0    Alice   25     New York     12
# 1      Bob   30  Los Angeles     25
# 2  Charlie   35      Chicago     65

# %%
df['number']
# Out:
# 0    12
# 1    25
# 2    65
# Name: number, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["id"] = ["369", "999", "951"]

# %%
df
# Out:
#       Name  Age         City number   id
# 0    Alice   25     New York     12  369
# 1      Bob   30  Los Angeles     25  999
# 2  Charlie   35      Chicago     65  951

# %%
df = pd.read_csv('./data/superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('./data/superstore.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df = pd.read_csv('./data/superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('./data/superstore.csv')
#
# ...

# %%
import pandas as pd
df = pd.read_csv("./data/dsuperstore.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('superstore.csv')
#
# File c:\Users\avinash\Downloads\my projects\machine learning projects\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print(os.path.exists('./data/superstore.csv'))
# Out:
# False

# %%
df = pd.read_csv('./data/superstore.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv('./data/superstore.csv', encoding='utf-8')
#
# File c:\Users\avinash\Downloads\my projects\machine learning projects\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print(os.path.exists('./data/superstoredata.csv'))
# Out:
# True

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 2.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.0 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.0 MB 3.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.0 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [10, 20, 30, 40, 50]
plt.plot(x, y, marker = '>', linestyle = '-', color = 'b', label = "sample plotline")
plt.xlabel("stock")
plt.ylabel("count")
plt.title("stock overview")
plt.legend()
plt.show()

# %%
import numpy as np
a = np.random.rand(20)
b = np.random.rand(20)

plt.scatter(a, b, color = "r", marker="*")
plt.xlabel("sample data 1")
plt.ylabel("sample data 2")
plt.title("scatter plot example")
# Out:
# Text(0.5, 1.0, 'scatter plot example')

# %%
categories = ['a', 'b', 'c', 'd', 'e']
values = [1, 2, 3, 4, 5]
plt.bar(categories, values, color = "blue")
plt.xlabel("categories")
plt.ylabel("values")
plt.title("bar chart")
plt.show()

# %%
plt.barh(categories, values, color="green")
plt.xlabel("values")
plt.ylabel("categories")
plt.title("horizontal bar chart")
plt.show()

# %%
import numpy as np
categories = ['a', 'b', 'c', 'd', 'e']
values = [10, 20, 30, 40, 50]
values2 = [12, 25,36,45,65]

x = np.arange(len(categories))
width = 0.3

plt.bar(x - width/2, values, width, label = "data1", color = "blue")
plt.bar(x + width/2, values2, width, label = "data2", color = "green")
plt.xticks(x, categories)
plt.xlabel("categories")
plt.ylabel("values")
plt.title("grouped bar chart")
plt.show()

# %%
fruits = ["apple", "orange", "banana", "pomogranete", "guava"]
price = [20, 35, 36, 50,40]
color = ["red", "green", "yellow", "blue", "pink"]

plt.pie(price, labels=fruits, colors=color, autopct="%1.1f%%", startangle=90)
plt.title("pie chart for fruit distributon")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

subjects = ["tamil", "eng", "cs", "sci", "soc", "hindi"]
marks = [89, 95, 78, 82, 56, 73]
plt.bar(subjects, marks, color = "yellow")
plt.show()

# %%
plt.figure(figsize=(12,8))
cl = ["red", 'blue', 'green', 'pink', 'orange', 'purple', 'yellow']
plt.barh(subjects, marks, color = cl,  edgecolor = "white",  linestyle = "-.")
plt.show()

# %%
subjects = ["tamil", "eng", "cs", "sci", "soc", "hindi"]
marks_1 = [89, 95, 78, 82, 56, 73]
marks_2 = [78, 56, 34, 39, 90, 23]
plt.figure(figsize=(9,7))
plt.bar(subjects, marks_1)
plt.bar(subjects, marks_2)
plt.xlabel("subjects")
plt.ylabel("marks")
plt.show()

# %%
subjects = ["tamil", "eng", "cs", "sci", "soc", "hindi"]
marks_1 = [89, 95, 78, 82, 56, 73]
marks_2 = [78, 56, 34, 39, 90, 23]
x = np.arange(len(subjects))
width = 0.4

plt.bar(x - width/2, marks_1, width, label = "data 1", color = "blue")
plt.bar(x + width/2, marks_2, width, label = "data 2", color = "green")
plt.xticks(x, subjects)
plt.xlabel("subjects")
plt.ylabel("marks")
plt.show()

# %%
subjects_len = np.arange(len(subjects))
width = 0.4

plt.figure(figsize=(12,8))

plt.bar(subjects, marks_1, width=width, color = cl)
plt.bar(subjects_len+width, marks_2, width=width, color=cl, alpha = 0.5)
plt.xlabel("subjects")
plt.ylabel("student marks")
plt.title("student mark analysis")
plt.show()

# %%
study_hours = [2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 11]
mark = [10, 15, 20, 14, 44, 55, 67, 70, 80, 90, 99, 100]

plt.scatter(study_hours, mark, color="blue", marker="o")
plt.show()

# %%
plt.plot(study_hours, mark)
plt.show()

# %%
plt.hist(mark)
plt.show()

# %%
plt.figure(figsize=(10, 10))  # Set figure size

# **1st Subplot - Scatter Plot**
plt.subplot(2, 2, 1)  
plt.scatter(study_hours, mark, color="blue")
plt.title("Scatter Plot")

# **2nd Subplot - Line Plot**
plt.subplot(2, 2, 2)  
plt.plot(study_hours, mark, 'r-')
plt.title("Line Plot")

# **3rd Subplot - Histogram**
plt.subplot(2, 2, 3)  
plt.hist(mark, bins=5, color="green", edgecolor="black")  
plt.title("Histogram")

# **4th Subplot - Combined Line + Scatter**
plt.subplot(2, 2, 4)  
plt.plot(study_hours, mark, 'r-', label="Line")  # Line plot
plt.plot(study_hours, mark, 'bo', label="Points")  # Scatter points
plt.title("Line + Scatter")
plt.legend()

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
data =  [22,34,23,22,45,43,41,35,21,25,29,30,32,31,26,28,34,37,39,40]
plt.hist(data, bins=10, edgecolor = "black")

plt.title("histogram of the given data")
plt.xlabel("data")
plt.ylabel("frequency")
plt.show()
